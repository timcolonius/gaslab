# %% [markdown]
# <!-- Reset -->
# <svg width="120" height="100" viewBox="0 0 120 100" xmlns="http://www.w3.org/2000/svg">
#   <g stroke="#4b5563" stroke-width="6" fill="none" stroke-linecap="round" stroke-linejoin="round">
#     <!-- 270° clockwise arc -->
#     <path d="M60 20
#              A30 30 0 1 1 30 50"/>
#     <!-- arrowhead pointing clockwise -->
#     <polyline points="20,60 30,50 40,60"/>
#   </g>
# </svg>
#
# <!-- Area -->
# <svg width="180" height="90" viewBox="0 0 180 90" xmlns="http://www.w3.org/2000/svg">
#   <g stroke="#4b5563" stroke-width="6" stroke-linecap="round" fill="none">
#     <path d="M20 20 L82 35 L160 20"/>
#     <path d="M20 70 L82 55 L160 70"/>
#     <line x1="45" y1="45" x2="135" y2="45"/>
#     <polyline points="120,35 135,45 120,55"/>
#   </g>
# </svg>
#
# <!-- Friction -->
# <svg width="220" height="90" viewBox="0 0 220 90" xmlns="http://www.w3.org/2000/svg">
#   <g stroke="#4b5563" stroke-width="6" stroke-linecap="round" fill="none">
#     <line x1="15" y1="22" x2="205" y2="22"/>
#     <line x1="15" y1="68" x2="205" y2="68"/>
#     <line x1="15" y1="45" x2="55" y2="45"/>
#     <path d="M65 45 C75 35, 85 55, 95 45
#              C105 35, 115 55, 125 45
#              C135 35, 145 55, 155 45
#              C165 35, 175 55, 185 45"/>
#     <line x1="185" y1="45" x2="205" y2="45"/>
#     <polyline points="190,35 205,45 190,55"/>
#   </g>
#   <text x="108" y="18" text-anchor="middle"
#         font-family="Arial, sans-serif" font-size="22" fill="#374151">+ μ</text>
# </svg>
#
# <!-- Heat -->
# <svg width="220" height="90" viewBox="0 0 220 90" xmlns="http://www.w3.org/2000/svg">
#   <g stroke="#4b5563" stroke-width="6" stroke-linecap="round" fill="none">
#     <line x1="15" y1="22" x2="205" y2="22"/>
#     <line x1="15" y1="68" x2="205" y2="68"/>
#     <line x1="15" y1="45" x2="55" y2="45"/>
#     <path d="M65 45 C75 35, 85 55, 95 45
#              C105 35, 115 55, 125 45
#              C135 35, 145 55, 155 45
#              C165 35, 175 55, 185 45"/>
#     <line x1="185" y1="45" x2="205" y2="45"/>
#     <polyline points="190,35 205,45 190,55"/>
#   </g>
#   <text x="108" y="18" text-anchor="middle"
#         font-family="Arial, sans-serif" font-size="22" fill="#374151">+ q</text>
# </svg>
#
# <!-- Shock -->
# <svg width="220" height="90" viewBox="0 0 220 90" xmlns="http://www.w3.org/2000/svg">
#   <g stroke="#4b5563" stroke-width="6" stroke-linecap="round" fill="none">
#     <line x1="15" y1="22" x2="205" y2="22"/>
#     <line x1="15" y1="68" x2="205" y2="68"/>
#     <line x1="20" y1="45" x2="110" y2="45"/>
#     <polyline points="95,35 110,45 95,55"/>
#     <line x1="125" y1="28" x2="125" y2="62" stroke="#d94841"/>
#     <line x1="140" y1="45" x2="185" y2="45"/>
#     <polyline points="170,35 185,45 170,55"/>
#   </g>
# </svg>
#
# <!-- Deflect -->
# <svg width="240" height="100" viewBox="0 0 240 100" xmlns="http://www.w3.org/2000/svg">
#   <g stroke="#4b5563" stroke-width="6" stroke-linecap="round" fill="none">
#     <line x1="15" y1="70" x2="95" y2="70"/>
#     <line x1="95" y1="70" x2="190" y2="54"/>
#     <line x1="25" y1="40" x2="95" y2="40"/>
#     <polyline points="80,30 95,40 80,50"/>
#     <line x1="95" y1="70" x2="155" y2="10" stroke="#4f46e5"/>
#     <line x1="145" y1="44" x2="190" y2="36"/>
#     <polyline points="177,30 190,36 179,46"/>
#   </g>
# </svg>
